# %% [markdown]
# ###**What are Declarative Automation Bundles?**
# Declarative Automation Bundles (DABs) are a feature in Databricks that lets you define, deploy, and manage Databricks resources as code. Instead of manually creating jobs, pipelines, clusters, permissions, and other resources through the UI, you describe them in YAML configuration files and deploy them consistently across environments.
